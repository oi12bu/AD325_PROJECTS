# %%
from stock_ledger import StockLedger
# I included print statements for the stock sales to show the net profit from each sale, though I know that 
# was not a part of the instructions for the assignment. I hope that is acceptable!
def main():
    my_stocks = StockLedger()
    my_stocks.buy("AAPL", 20, 45.00)
    my_stocks.buy("AAPL", 20, 75.00)
    my_stocks.buy("MSFT", 20, 95.00)
    print(my_stocks.display_ledger())

    print(my_stocks.sell("AAPL", 30, 65.00))
    print(my_stocks.display_ledger())
    
    print(my_stocks.sell("AAPL", 10, 65.00))
    print(my_stocks.display_ledger())

    my_stocks.buy("AAPL", 100, 20.00)
    my_stocks.buy("AAPL", 20, 24.00)
    my_stocks.buy("TSLA", 200, 36.00)
    print(my_stocks.display_ledger())

    print(my_stocks.sell("AAPL", 10, 65.00))
    print(my_stocks.display_ledger())

    print(my_stocks.sell("TSLA", 150, 30.00))
    print(my_stocks.display_ledger())

    my_stocks.buy("MSFT", 5, 60.00)
    my_stocks.buy("MSFT", 5, 70.00)
    print(my_stocks.display_ledger())

    print(my_stocks.sell("MSFT", 4, 30.00))
    print(my_stocks.display_ledger())

    print(my_stocks.sell("MSFT", 2, 30.00))
    print(my_stocks.display_ledger())

main()
# Out:
# ---- Stock Ledger ----
# AAPL: $45.00 (20 shares), $75.00 (20 shares)
# MSFT: $95.00 (20 shares)
#
# Net prefit of sale : $300.00
#
# ---- Stock Ledger ----
# AAPL: $75.00 (10 shares)
# MSFT: $95.00 (20 shares)
#
# Net prefit of sale : $-100.00
#
# ---- Stock Ledger ----
# AAPL: No shares owned
# MSFT: $95.00 (20 shares)
#
# ---- Stock Ledger ----
# AAPL: $20.00 (100 shares), $24.00 (20 shares)
# MSFT: $95.00 (20 shares)
# TSLA: $36.00 (200 shares)
#
# Net prefit of sale : $450.00
#
# ---- Stock Ledger ----
# AAPL: $20.00 (90 shares), $24.00 (20 shares)
# MSFT: $95.00 (20 shares)
# TSLA: $36.00 (200 shares)
#
# Net prefit of sale : $-900.00
#
# ---- Stock Ledger ----
# AAPL: $20.00 (90 shares), $24.00 (20 shares)
# MSFT: $95.00 (20 shares)
# TSLA: $36.00 (50 shares)
#
# ---- Stock Ledger ----
# AAPL: $20.00 (90 shares), $24.00 (20 shares)
# MSFT: $95.00 (20 shares), $60.00 (5 shares), $70.00 (5 shares)
# TSLA: $36.00 (50 shares)
#
# Net prefit of sale : $-260.00
#
# ...
