# %% [markdown]
# #### This notebook contains the main logic for Project 3: Patient Record Management

# %%
from patient_record_mgmt import PatientRecordManagementSystem
from graphviz import Digraph

# %%
def main():
    patient_records = PatientRecordManagementSystem()
    patient_records.build_tree_from_csv('data\patient_records.csv')
    patient_2 = patient_records.search_patient_record(2)
    print(patient_2)
    patient_25 = patient_records.search_patient_record(25)
    print(patient_25)
    patient_47 = patient_records.search_patient_record(47)
    print(patient_47)
    patient_records.delete_patient_record('3')
    patient_records.delete_patient_record('10')
    patient_records.delete_patient_record('30')
    dot = patient_records.visualize_tree()
    dot.render('patient_records_tree_after-deletion.dot', view = False)


if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 18
#      14     dot.render('patient_records_tree_after-deletion.dot', view = False)
#      17 if __name__ == "__main__":
# ---> 18     main()
#
# Cell In[6], line 4, in main()
#       2 patient_records = PatientRecordManagementSystem()
#       3 patient_records.build_tree_from_csv('data\patient_records.csv')
# ----> 4 patient_2 = patient_records.search_patient_record(2)
#       5 print(patient_2)
#       6 patient_25 = patient_records.search_patient_record(25)
#
# File c:\Users\oi12b\.anaconda\AD325_PROJECTS\project_03\patient_record_mgmt.py:26, in PatientRecordManagementSystem.search_patient_record(self, patient_id)
#      25 def search_patient_record(self, patient_id):
# ---> 26     node = self.bst.search(patient_id)
#      27     if node:
#      28         return node
#
# File c:\Users\oi12b\.anaconda\AD325_PROJECTS\project_03\binary_search_tree.py:25, in BinarySearchTree.search(self, desired_key)
#      21     return current_node
#      23 # Navigate to the left if the search key is
#      24 # less than the node's key.
# ---> 25 elif desired_key < current_node.key:
#      26     current_node = current_node.left
#      28 # Navigate to the right if the search key is
#      29 # greater than the node's key.
#      30 else:
#
# TypeError: '<' not supported between instances of 'int' and 'str'
