# %% [markdown]
# #### This notebook contains the main logic for Project 3: Patient Record Management

# %%
from patient_record_mgmt import PatientRecordManagementSystem
from graphviz import Digraph

# %%
def main():
    patient_records = PatientRecordManagementSystem()
    patient_records.build_tree_from_csv('data\patient_records.csv')
    2 = patient_records.search_patient_record('2')
    print(2.value)
    25 = patient_records.search_patient_record('25')
    print(25.value)
    47 = patient_records.search_patient_record('47')
    print(47.value)
    patient_records.delete_patient_record('3')
    patient_records.delete_patient_record('10')
    patient_records.delete_patient_record('30')
    dot = patient_records.visualize_tree()
    dot.render('patient_records_tree_after-deletion.dot', view = False)


if __name__ == "__main__":
    main()
# Out:
# None
# <patient_record_mgmt.PatientRecord object at 0x000001A7D4286EA0>
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 15
#      11     dot.render('patient_records_tree_after-deletion.dot', view = False)
#      14 if __name__ == "__main__":
# ---> 15     main()
#
# Cell In[2], line 7, in main()
#       5 print(patient_records.search_patient_record('25'))
#       6 print(patient_records.search_patient_record('47'))
# ----> 7 patient_records.delete_patient_record('3')
#       8 patient_records.delete_patient_record('10')
#       9 patient_records.delete_patient_record('30')
#
# File c:\Users\oi12b\.anaconda\AD325_PROJECTS\project_03\patient_record_mgmt.py:35, in PatientRecordManagementSystem.delete_patient_record(self, patient_id)
#      33 node = self.bst.search(patient_id)
#      34 if node:
# ---> 35     node.remove()
#
# AttributeError: 'Node' object has no attribute 'remove'
